# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
import requests

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product vertical
# from www.amazon.in. The product verticals to be searched will be taken as input from user.
# For e.g. If user input is ‘guitar’. Then search for guitars

# %%
driver1=webdriver.Chrome('chromedriver.exe')
url='https://www.amazon.in/'
driver1.get(url)

# %%
search=driver1.find_element_by_id('twotabsearchtextbox')
search.send_keys('tv')

# %%
button=driver1.find_element_by_id('nav-search-submit-button').click()

# %% [markdown]
# # In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a data frame and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“

# %%
Url1=[]

for i in range(1,4):
    pg='https://www.amazon.in/s?k=tv&page=2&qid=1632481982&ref=sr_pg_'+str(i)
    driver1.get(pg)
    url_tag=driver1.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a[1]")
    for j in url_tag:
        Url1.append(j.get_attribute('href'))

len(Url1)
# Out:
# 66

# %%
Brand_Name=[]

for i in Url1:
    driver1.get(i)
    time.sleep(1)
    bn=driver1.find_element_by_xpath("//span[@class='a-size-large product-title-word-break']")
    Brand_Name.append(bn.text)
    
len(Brand_Name)
# Out:
# 66

# %%
Rating=[]
No_Of_Rating=[]

for i in Url1:
    driver1.get(i)
    time.sleep(1)
    try:
        rt=driver1.find_element_by_xpath("//div[@class='a-section a-spacing-none a-spacing-top-mini cr-widget-ACR']/div[2]/span[1]")
        Rating.append(rt.text)
    except:
        Rating.append("-")

# %%
No_Of_Rating=[]
Price=[]
Delivery_Date=[]
Rating=[]
Return=[]
Avability=[]


for i in Url1:
    driver1.get(i)
    time.sleep(2)
    pr=driver1.find_element_by_xpath("//span[@class='a-size-medium a-color-price priceBlockBuyingPriceString']")
    Price.append(pr.text)
    dd=driver1.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
    Delivery_Date.append(dd.text)
    
    rtn=driver1.find_element_by_xpath("//div[@class='a-column a-span3 a-text-center icon-container icon-grid-width celwidget']//a[1]")
    Return.append(rtn.text)
    avl=driver1.find_element_by_xpath("//div[@class='a-section a-spacing-base }']/span")
    Avability.append(avl.text)

# %%
df2=pd.DataFrame()

df2['Name Of Product']=Brand_Name
df2['No Of Rating']=Rating
df2['Price']=Price
df2['Return']=Return
df2['Delivery Date']=Delivery_Date
df2['Avability']=Avability

df2
# Out:
#                                       Name Of Product          No Of Rating  \
# 0   Samsung 125 cm (50 inches) The Frame Series 4K...  2,219 global ratings
# 1   Samsung 138 cm (55 inches) Crystal 4K Pro Seri...    251 global ratings
# 2   Samsung 80 cm (32 Inches) HD Ready LED TV UA32...  3,060 global ratings
# 3   Samsung 80 cm (32 inches) Wondertainment Serie...  8,849 global ratings
# 4   Kodak 102 cm (40 Inches) Full HD Certified And...  8,478 global ratings
# ..                                                ...                   ...
# 61  VW 100 cm (40 inches) HD Ready Smart LED TV VW...      3 global ratings
# 62  AKAI 98 cm (40 inches) Full HD Smart LED TV AK...    301 global ratings
# 63  Kevin 60 cm (24 Inches) HD Ready Smart LED TV ...                     -
# 64  AmazonBasics 139cm (55 inch) 4K Ultra HD Smart...  6,422 global ratings
# 65  Redmi 126 cm (50 inches) 4K Ultra HD Android S...  4,178 global ratings
#
#          Price               Return               Delivery Date  Avability
# 0   ₹38,990.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 1   ₹77,990.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 2   ₹16,290.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 3   ₹19,240.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 4   ₹20,989.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# ..         ...                  ...                         ...        ...
# 61  ₹22,500.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 62  ₹43,999.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 63  ₹10,299.00  10 Days Replacement  Wednesday, Sep 29, 8AM-5PM  In stock.
# 64  ₹18,999.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
# 65  ₹38,999.00  10 Days Replacement     Monday, Sep 27, 8AM-2PM  In stock.
#
# [66 rows x 6 columns]

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
driver3=webdriver.Chrome('chromedriver.exe')
url3='https://www.google.com/imghp?hl=en'
driver3.get(url3)

# %%
keyword=driver3.find_element_by_xpath("//input[@class='gLFyf gsfi']")
keyword.send_keys('fruits')

# %%
search=driver3.find_element_by_xpath("//button[@class='Tg7LZd']").click()

# %%
image=driver3.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
len(image)
# Out:
# 200

# %%
Fruits=[]

try:
    for i in image:
        Fruits.append(i.get_attribute('src'))
except:
    Fruits.append('-')
    
len(Fruits)
# Out:
# 200

# %%
driver3.get(url3)
keyword=driver3.find_element_by_xpath("//input[@class='gLFyf gsfi']")
keyword.send_keys('cars')

# %%
search=driver3.find_element_by_xpath("//button[@class='Tg7LZd']").click()

# %%
car=driver3.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
len(car)
# Out:
# 200

# %%
Car=[]

for i in car:
    Car.append(i.get_attribute('src'))
    
len(Car)
# Out:
# 200

# %%
driver3.get(url3)
keyword=driver3.find_element_by_xpath("//input[@class='gLFyf gsfi']")
keyword.send_keys('Machine Learning')

# %%
search=driver3.find_element_by_xpath("//button[@class='Tg7LZd']").click()

# %%
ml=driver3.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
len(ml)
# Out:
# 200

# %%
ML=[]

for i in ml:
    try:
        ML.append(i.get_attribute('src'))
    except:
        ML.append("-")
    
len(ML)
# Out:
# 200

# %%
df3=pd.DataFrame()

# %%
df3['fruits']=Fruits
df3['Cars']=Car
df3['Machine Learning']=ML
df3[0:100]
# Out:
#                                                fruits  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                                  Cars  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                      Machine Learning
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
driver4=webdriver.Chrome('chromedriver.exe')
url4='http://www.flipkart.com/'
driver4.get(url4)

# %%
search=driver4.find_element_by_xpath("//input[@class='_3704LK']")
search.send_keys('reno 6 pro')

# %%
btn=driver4.find_element_by_xpath("//button[@class='L0Z3Pu']").click()

# %%
SmartPhone_Name=[]
Brand_Name=[]
Url4=[]

sp_name=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in sp_name:
    SmartPhone_Name.append(i.text)

bn=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in bn:
    Brand_Name.append(i.text[0:5])
    
url=driver4.find_elements_by_xpath("//a[@class='_1fQZEK']")
for i in url:
    Url4.append(i.get_attribute('href'))

# %%
Model_No=[]
Color=[]
Price=[]

for i in Url4:
    driver4.get(i)
    m=driver4.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']//table[1]//tr[2]//td[2]//li[1]")
    Model_No.append(m.text)
    clr=driver4.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']//table[1]//tr[4]//td[2]//li[1]")
    Color.append(clr.text)
    prc=driver4.find_element_by_xpath("//div[@class='_25b18c']//div[1]")
    Price.append(prc.text)

# %%
dis=[]
res=[]
pros_type=[]
pros_core=[]
rom=[]
ram=[]
pr_cam=[]
sec_cam=[]
battery=[]

for i in Url4:
    driver4.get(i)
    driver4.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    time.sleep(1)
    model=driver4.find_elements_by_xpath("//tr[@class='_1s_Smc row']")
    for n in model:
        text1=n.find_element_by_xpath("td[1]").text
        if text1=='Display Size':
            dis.append(n.find_element_by_xpath('td[2]').text)
        if text1=='Resolution':
            res.append(n.find_element_by_xpath('td[2]').text)
            
            
        try:
            if text1=='Processor Type':
                pros_type.append(n.find_element_by_xpath('td[2]').text)
        except:
            pros_type.append("-")
                                 
        if text1=='Processor Core':
            pros_core.append(n.find_element_by_xpath('td[2]').text)
        if text1=='Internal Storage':
            rom.append(n.find_element_by_xpath('td[2]').text)
        if text1=='RAM':
            ram.append(n.find_element_by_xpath('td[2]').text)
        if text1=='Battery Capacity':
            battery.append(n.find_element_by_xpath('td[2]').text)
        if text1=='Primary Camera':
            pr_cam.append(n.find_element_by_xpath('td[2]').text)
        if text1=='Secondary Camera':
            sec_cam.append(n.find_element_by_xpath('td[2]').text)

# %%
df4=pd.DataFrame()

df4['Brand Name']=Brand_Name
df4['Smartphone Name']=SmartPhone_Name
df4['Model No.']=Model_No
df4['Color']=Color
df4['RAM']=ram
df4['ROM']=rom
df4['Primary Camara']=pr_cam
df4['Secondary Camara']=sec_cam
df4['Dispaly']=dis
df4['Resoluation']=res
df4['Processor']=pros_type
df4['Processor Core']=pros_core
df4['Battery Capacity']=battery
df4['Price']=Price
df4['Product URL']=Url4

df4
# Out:
#    Brand Name                                    Smartphone Name Model No.  \
# 0       OPPO           OPPO Reno6 Pro 5G (Stellar Black, 256 GB)   CPH2249
# 1       OPPO                  OPPO Reno6 Pro 5G (Aurora, 256 GB)   CPH2249
# 2       OPPO             OPPO Reno5 Pro 5G (Astral Blue, 128 GB)   CPH2201
# 3       OPPO                OPPO Reno4 Pro (Silky White, 128 GB)   CPH2109
# 4       OPPO             OPPO Reno3 Pro (Midnight Black, 256 GB)   CPH2035
# 5       OPPO               OPPO Reno3 Pro (Auroral Blue, 256 GB)   CPH2035
# 6       OPPO               OPPO Reno3 Pro (Auroral Blue, 128 GB)   CPH2035
# 7       OPPO            OPPO Reno5 Pro 5G (Starry Black, 128 GB)   CPH2201
# 8       OPPO                  OPPO Reno3 Pro (Sky White, 128 GB)   CPH2035
# 9       OPPO             OPPO Reno3 Pro (Midnight Black, 128 GB)   CPH2035
# 10      OPPO               OPPO Reno4 Pro (Starry Night, 128 GB)   CPH2109
# 11      OPPO   OPPO Reno4 Pro Special Edition (Galactic Blue,...   CPH2109
# 12      OPPO   OPPO Reno4 Pro Special Edition (Starry Night, ...   CPH2109
# 13      OPPO                  OPPO Reno3 Pro (Sky White, 256 GB)   CPH2035
#
#              Color    RAM     ROM           Primary Camara  \
# 0    Stellar Black  12 GB  256 GB   64MP + 8MP + 2MP + 2MP
# 1           Aurora  12 GB  256 GB   64MP + 8MP + 2MP + 2MP
# 2      Astral Blue   8 GB  128 GB   64MP + 8MP + 2MP + 2MP
# 3      Silky White   8 GB  128 GB   48MP + 8MP + 2MP + 2MP
# 4   Midnight Black   8 GB  256 GB  64MP + 13MP + 8MP + 2MP
# 5     Auroral Blue   8 GB  256 GB  64MP + 13MP + 8MP + 2MP
# 6     Auroral Blue   8 GB  128 GB  64MP + 13MP + 8MP + 2MP
# 7     Starry Black   8 GB  128 GB   64MP + 8MP + 2MP + 2MP
# 8        Sky White   8 GB  128 GB  64MP + 13MP + 8MP + 2MP
# 9   Midnight Black   8 GB  128 GB  64MP + 13MP + 8MP + 2MP
# 10    Starry Night   8 GB  128 GB   48MP + 8MP + 2MP + 2MP
# 11   Galactic Blue   8 GB  128 GB   48MP + 8MP + 2MP + 2MP
# 12    Starry Night   8 GB  128 GB   48MP + 8MP + 2MP + 2MP
# 13       Sky White   8 GB  256 GB  64MP + 13MP + 8MP + 2MP
#
#                 Secondary Camara               Dispaly         Resoluation  \
# 0              32MP Front Camera  16.64 cm (6.55 inch)  2400 x 1080 Pixels
# 1              32MP Front Camera  16.64 cm (6.55 inch)  2400 x 1080 Pixels
# 2              32MP Front Camera  16.64 cm (6.55 inch)  2400 x 1080 Pixels
# 3              32MP Front Camera   16.51 cm (6.5 inch)  2400 x 1080 Pixels
# 4   44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
# 5   44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
# 6   44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
# 7              32MP Front Camera  16.64 cm (6.55 inch)  2400 x 1080 Pixels
# 8   44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
# 9   44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
# 10             32MP Front Camera   16.51 cm (6.5 inch)  2400 x 1080 Pixels
# 11             32MP Front Camera   16.51 cm (6.5 inch)  2400 x 1080 Pixels
# 12             32MP Front Camera   16.51 cm (6.5 inch)  2400 x 1080 Pixels
# 13  44MP + 2MP Dual Front Camera   16.26 cm (6.4 inch)  2400 x 1080 Pixels
#
#                              Processor Processor Core Battery Capacity  \
# 0              MediaTek Dimensity 1200      Octa Core         4500 mAh
# 1              MediaTek Dimensity 1200      Octa Core         4500 mAh
# 2    MediaTek Dimensity 1000+ (MT6889)      Octa Core         4350 mAh
# 3   Qualcomm Snapdragon 720G Octa Core      Octa Core         4000 mAh
# 4                   MediaTek Helio P95      Octa Core         4025 mAh
# 5                   MediaTek Helio P95      Octa Core         4025 mAh
# 6                   MediaTek Helio P95      Octa Core         4025 mAh
# 7    MediaTek Dimensity 1000+ (MT6889)      Octa Core         4350 mAh
# 8                   MediaTek Helio P95      Octa Core         4025 mAh
# 9                   MediaTek Helio P95      Octa Core         4025 mAh
# 10  Qualcomm Snapdragon 720G Octa Core      Octa Core         4000 mAh
# 11  Qualcomm Snapdragon 720G Octa Core      Octa Core         4000 mAh
# 12  Qualcomm Snapdragon 720G Octa Core      Octa Core         4000 mAh
# 13                  MediaTek Helio P95      Octa Core         4025 mAh
#
#       Price                                        Product URL
# 0   ₹39,990  https://www.flipkart.com/oppo-reno6-pro-5g-ste...
# 1   ₹39,990  https://www.flipkart.com/oppo-reno6-pro-5g-aur...
# 2   ₹35,990  https://www.flipkart.com/oppo-reno5-pro-5g-ast...
# 3   ₹34,990  https://www.flipkart.com/oppo-reno4-pro-silky-...
# 4   ₹26,818  https://www.flipkart.com/oppo-reno3-pro-midnig...
# 5   ₹25,989  https://www.flipkart.com/oppo-reno3-pro-aurora...
# 6   ₹25,114  https://www.flipkart.com/oppo-reno3-pro-aurora...
# 7   ₹35,990  https://www.flipkart.com/oppo-reno5-pro-5g-sta...
# 8   ₹24,719  https://www.flipkart.com/oppo-reno3-pro-sky-wh...
# 9   ₹24,788  https://www.flipkart.com/oppo-reno3-pro-midnig...
# 10  ₹34,990  https://www.flipkart.com/oppo-reno4-pro-starry...
# 11  ₹34,990  https://www.flipkart.com/oppo-reno4-pro-specia...
# 12  ₹34,990  https://www.flipkart.com/oppo-reno4-pro-specia...
# 13  ₹27,990  https://www.flipkart.com/oppo-reno3-pro-sky-wh...

# %% [markdown]
# Saving DataFrame into CSV Formate

# %%
df4.to_csv('df4.csv')

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on
# google maps.

# %%
driver5=webdriver.Chrome('chromedriver.exe')
url5='https://www.google.com/maps'
driver5.get(url5)

# %%
box=driver5.find_element_by_xpath("//input[@class='tactile-searchbox-input']")
box.send_keys('Rajkot')

# %%
btn=driver5.find_element_by_xpath("//button[@class='searchbox-searchbutton']").click()

# %%
current_url=driver5.current_url

# %%
import re

# %%
try:
    latitude=re.findall('(\d+(\.\d*)?)',current_url)[0]
    longitude=re.findall('(\d+(\.\d*)?)',current_url)[1]
    print("Geospatial coordinate of Rajkot Are:")
    print("Latitude",latitude[0])
    print("Longitute",longitude[0])
except Exception as e:
    print("Error:",str(e))
# Out:
# Geospatial coordinate of Rajkot Are:
# Latitude 22.273487
# Longitute 70.8212963

# %% [markdown]
# # 6 Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in.

# %%
driver6=webdriver.Chrome('chromedriver.exe')
url6='https://trak.in/india-startup-funding-investment-2015/'
driver6.get(url6)

# %%
Date=[]
date=driver6.find_elements_by_xpath("//td[@class='column-2']")

for i in date:
    Date.append(i.text)
    
len(Date)
# Out:
# 392

# %%
StartUp=[]
startup=driver6.find_elements_by_xpath("//td[@class='column-3']")

for i in startup:
    StartUp.append(i.text)
    
len(StartUp)
# Out:
# 392

# %%
Industry=[]
ind=driver6.find_elements_by_xpath("//td[@class='column-4']")

for i in ind:
    Industry.append(i.text)
    
print(len(Industry))
# Out:
# 392

# %%
Sub_Vertical=[]
sv=driver6.find_elements_by_xpath("//td[@class='column-5']")

for i in sv:
    Sub_Vertical.append(i.text)
    
print(len(Sub_Vertical))
# Out:
# 392

# %%
City=[]
city=driver6.find_elements_by_xpath("//td[@class='column-6']")

for i in city:
    City.append(i.text)
    
print(len(City))
# Out:
# 392

# %%
Investor_Name=[]
inname=driver6.find_elements_by_xpath("//td[@class='column-7']")

for i in inname:
    Investor_Name.append(i.text)
    
print(len(Investor_Name))
# Out:
# 392

# %%
Investor_Type=[]
it=driver6.find_elements_by_xpath("//td[@class='column-8']")

for i in it:
    Investor_Type.append(i.text)
    
print(len(Investor_Type))
# Out:
# 392

# %%
Amount=[]
amt=driver6.find_elements_by_xpath("//td[@class='column-9']")

for i in amt:
    Amount.append(i.text)
    
print(len(Amount))
# Out:
# 392

# %%
df6=pd.DataFrame()

df6['Date']=Date[55:85]
df6['StartUp_Name']=StartUp[55:85]
df6['Industry/Vertical']=Industry[55:85]
df6['Sub-Vertical']=Sub_Vertical[55:85]
df6['City/Location']=City[55:85]
df6['Investor_Name']=Investor_Name[55:85]
df6['Investor_Type']=Investor_Type[55:85]
df6['Amount(In USD)']=Amount[55:85]

df6
# Out:
#           Date               StartUp_Name  \
# 0   08/09/2020                     Byju’s
# 1   12/09/2020                  mCaffeine
# 2   09/09/2020                     Qshala
# 3   02/09/2020                      Winzo
# 4   09/09/2020                Hippo Video
# 5   07/09/2020                    Melorra
# 6   07/09/2020                        1mg
# 7   31/08/2020                      mfine
# 8   31/08/2020                       Apna
# 9   03/09/2020                    Railofy
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  15/07/2020                   Flipkart
# 21  16/07/2020                    Vedantu
# 22  16/07/2020                       Crio
# 23  14/07/2020                    goDutch
# 24  13/07/2020                   Mystifly
# 25  09/07/2020               JetSynthesys
# 26  10/07/2020                   gigIndia
# 27  15/07/2020                  PumPumPum
# 28  14/07/2020                       FLYX
# 29  13/07/2020  Open Appliances Pvt. Ltd.
#
#                          Industry/Vertical  \
# 0                                  EduTech
# 1                            Personal Care
# 2                                  EduTech
# 3                            Online Gaming
# 4   Video Customer Experience(CX) Platform
# 5                               E-commerce
# 6                               E-commerce
# 7                               HealthTech
# 8                          Human Resources
# 9                           Transportation
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                              E-commerce
# 21                                 EduTech
# 22                                 EduTech
# 23                                 FinTech
# 24                     Airfare Marketplace
# 25                Gaming and Entertainment
# 26                             Marketplace
# 27                       Automotive Rental
# 28                              OTT Player
# 29                  Information Technology
#
#                                          Sub-Vertical  \
# 0                                     Online Tutoring
# 1                                 Skincare & Haircare
# 2                  Online Curiosity Platform for Kids
# 3                                       Online Gaming
# 4              Video Customer Experience(CX) Platform
# 5                                Online Jewelry Store
# 6                                     Online Pharmacy
# 7                       On-Demand Healthcare Services
# 8                                Recruitment Platform
# 9                        WL & RAC protection platform
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                         E-commerce
# 21                                    Online Tutoring
# 22                   Learning Platform for Developers
# 23                                     Group Payments
# 24  Ticketing, Airline Retailing, and Post-Ticketi...
# 25                           Gaming and Entertainment
# 26                          Crowd Sourcing, Freelance
# 27                          Used Car-leasing platform
# 28                           Streaming Social Network
# 29              Internet-of-Things Security Solutions
#
#                                  City/Location  \
# 0                                    Bangalore
# 1                                       Mumbai
# 2                                    Bangalore
# 3                                    New Delhi
# 4   Newark, Delaware, United States of Amercia
# 5                                    Bangalore
# 6                                      Gurgaon
# 7                                    Bangalore
# 8                                    Bangalore
# 9                                       Mumbai
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                   Bangalore
# 23                                      Mumbai
# 24                     Singapore and Bangalore
# 25                                        Pune
# 26                                        Pune
# 27                                     Gurgaon
# 28                          New York and Delhi
# 29                                   Bangalore
#
#                                         Investor_Name           Investor_Type  \
# 0   Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 1   Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 2                                  Rainmatter Capital                   Angel
# 3   Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 4   Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 5                          Shadow Holdings, Lightbox.          Debt Financing
# 6          Gaja Capital, Tata Capital, Partners Group             In Progress
# 7                                    Caretech Pte Inc                Series B
# 8          Lightspeed India and Sequoia Capital India                Series A
# 9                                   Chiratae Ventures                    Seed
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20                                        Walmart Inc                     M&A
# 21                                  Coatue Management                Series D
# 22                                        021 Capital            pre-Series A
# 23  Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 24                                   Recruit Co. Ltd.            pre-Series B
# 25           Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 26       Incubate Fund India and Beyond Next Ventures            pre-Series A
# 27                           Early Adapters Syndicate                    Seed
# 28              Raj Mishra, founder of AIT Global Inc                pre-Seed
# 29                             Unicorn India Ventures  Venture-Series Unknown
#
#      Amount(In USD)
# 0       500,000,000
# 1         3,000,000
# 2           370,000
# 3        15,500,000
# 4         4,500,000
# 5    upto 8,900,000
# 6       100,000,000
# 7         5,400,000
# 8         8,000,000
# 9           950,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20    1,200,000,000
# 21      100,000,000
# 22          934,160
# 23        1,700,000
# 24        3,300,000
# 25          400,000
# 26          974,200
# 27          292,800
# 28          200,000
# 29          500,000

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver7=webdriver.Chrome('chromedriver.exe')
url='https://www.digit.in/top-products/best-gaming-laptops-40.html'
driver7.get(url)

# %%
Laptop_Name=[]
ln=driver7.find_elements_by_xpath("//div[@class='TopNumbeHeading active sticky-footer']")

for i in ln:
    Laptop_Name.append(i.text.replace('\n',''))

len(Laptop_Name)
# Out:
# 7

# %%
OS=[]
os=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]")

for i in os:
    OS.append(i.text.replace("OS",' '))
len(OS)
# Out:
# 7

# %%
Display=[]
dsply=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]")

for i in dsply:
    Display.append(i.text.replace("Display :",' '))
len(Display)
# Out:
# 7

# %%
Detail=[]
dtl=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]")

for i in dtl:
    Detail.append(i.text.replace("Memory",' '))
len(Detail)
# Out:
# 7

# %%
Weight=[]
dtl=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]")

for i in dtl:
    Weight.append(i.text.replace("Weight",''))
len(Weight)
# Out:
# 7

# %%
Graphics=[]
dtl=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]")

for i in dtl:
    Graphics.append(i.text.replace("Graphics Processor",' '))
len(Graphics)
# Out:
# 7

# %%
Dimension=[]
dtl=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]")

for i in dtl:
    Dimension.append(i.text.replace("Dimension :",' '))
len(Dimension)
# Out:
# 7

# %%
Processor=[]
dtl=driver7.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]")

for i in dtl:
    Processor.append(i.text.replace("Processor :",' '))
len(Processor)
# Out:
# 7

# %%
Seller=[]
slr=driver7.find_elements_by_xpath("//td[@class='smmerchant']")

for i in slr:
    Seller.append(i.text)
len(Seller)
# Out:
# 7

# %%
Price=[]
price=driver7.find_elements_by_xpath("//td[@class='smprice']")

for i in price:
    Price.append(i.text)
len(Price)
# Out:
# 7

# %%
df7=pd.DataFrame()

df7['Laptop_Name']=Laptop_Name
df7['OS']=OS
df7['Display']=Display
df7['processor']=Processor
df7['Memory']=Detail
df7['Weight']=Weight
df7['Dimension']=Dimension
df7['Graphics_Processor']=Graphics
df7['Seller']=Seller
df7['Price']=Price

df7
# Out:
#                   Laptop_Name                   OS                Display  \
# 0     1.ALIENWARE AREA 51M R2    : Windows 10 Home    17.3" (1920 x 1080)
# 1          2.ALIENWARE M15 R3    : Windows 10 Home    15.6" (3840 x 2160)
# 2    3.ASUS ROG STRIX SCAR 15    : Windows 10 Home    15.6" (1920 x 1080)
# 3     4.ASUS ROG ZEPHYRUS G14    : Windows 10 Home      14" (1920 x 1080)
# 4          5.LENOVO LEGION 5I     : Windows 10 Pro    15.6" (1920 x 1080)
# 5  6.ASUS ROG ZEPHYRUS DUO 15         : Windows 10    15.6" (3840 x 1100)
# 6      7.ACER ASPIRE 7 GAMING    : Windows 10 Home    15.6" (1920 x 1080)
#
#                                            processor  \
# 0    10th Generation Intel® Core™ i7-10700 | 2.90...
# 1       10th Generation Intel® Core™ i9-10980HK | NA
# 2                      AMD Ryzen™ 9 5900HX | 3.3 GHz
# 3               AMD 3rd Generation Ryzen 9 | 3.3 GHz
# 4    10th Generation Intel® Core™ i5-10300H | 2.5...
# 5                 Intel Core i7 10th Gen 10875H | NA
# 6                  AMD Ryzen™ 5-5500U hexa-core | NA
#
#                        Memory   Weight                  Dimension  \
# 0     : 1 TB SSD/16 GBGB DDR4    : 4.1     27.65 x 402.6 x 319.14
# 1     : 1 TB SSD/16 GBGB DDR4     : NA                         NA
# 2     : 1 TB SSD/16 GBGB DDR4   : 2.30         35.4 x 25.9 x 2.26
# 3     : 1 TB SSD/16 GBGB DDR4   : 1.65          32.5 x 22.1 x 1.8
# 4     : 1 TB SSD/16 GBGB DDR4    : 2.3    363.06 x 259.61 x 23.57
# 5    : 512 GB SSD/4 GBGB DDR4    : 2.4    268.30 x 360.00 x 20.90
# 6    : 512 GB SSD/8 GBGB DDR4   : 2.15         2.29 x 36.3 x 25.4
#
#                   Graphics_Processor  Seller      Price
# 0          : Intel® UHD Graphics 630     N/A        N/A
# 1                               : NA     N/A  ₹ 341,990
# 2        : NVIDIA® GeForce RTX™ 3070     N/A        N/A
# 3          : NVIDIA GeForce RTX 2060  Amazon  ₹ 164,990
# 4    : NVIDIA® GeForce® GTX 1650 4GB  Amazon   ₹ 76,988
# 5    : NVIDIA GeForce RTX 2070 Max-Q  Amazon  ₹ 185,000
# 6        : NVIDIA® GeForce® GTX 1650  Amazon   ₹ 64,370

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com.
# Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”,
# “Industry”

# %%
driver8=webdriver.Chrome('chromedriver.exe')
url8=('https://www.forbes.com/billionaires/')
driver8.get(url8)

# %%
Rank=[]
rank=driver8.find_elements_by_xpath("//div[@class='rank']")

for i in rank:
    Rank.append(i.text)
    
len(Rank)
# Out:
# 200

# %%
Name=[]
name=driver8.find_elements_by_xpath("//div[@class='personName']")

for i in name:
    Name.append(i.text)
    
len(Name)
# Out:
# 200

# %%
Net_Worth=[]
nw=driver8.find_elements_by_xpath("//div[@class='netWorth']")

for i in nw:
    Net_Worth.append(i.text)
    
len(Net_Worth)
# Out:
# 200

# %%
Age=[]
age=driver8.find_elements_by_xpath("//div[@class='age']")

for i in age:
    Age.append(i.text)
    
len(Age)
# Out:
# 200

# %%
Country=[]
cntry=driver8.find_elements_by_xpath("//div[@class='countryOfCitizenship']")

for i in cntry:
    Country.append(i.text)
    
len(Country)
# Out:
# 200

# %%
Source=[]
suc=driver8.find_elements_by_xpath("//div[@class='source-column']")

for i in suc:
    Source.append(i.text)

len(Source)
# Out:
# 200

# %%
Industry=[]
ind=driver8.find_elements_by_xpath("//div[@class='category']/div")

for i in ind:
    Industry.append(i.text)
    
len(Industry)
# Out:
# 200

# %%
df8=pd.DataFrame()

df8['Rank']=Rank
df8['Name']=Name
df8['Net_Worth']=Net_Worth
df8['Age']=Age
df8['Citizenship']=Country
df8['Source']=Source
df8['Industry']=Industry

df8
# Out:
#      Rank                      Name Net_Worth  Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B   77  United States
# 1      2.                 Elon Musk    $151 B  N/A  United States
# 2      3.  Bernard Arnault & family    $150 B   76         France
# 3      4.                Bill Gates    $124 B   85  United States
# 4      5.           Mark Zuckerberg     $97 B   94  United States
# ..    ...                       ...       ...  ...            ...
# 195  195.           Harry Triguboff   $11.2 B   75      Australia
# 196  197.     Leonid Fedun & family   $11.1 B   86         Russia
# 197  197.                 Eyal Ofer   $11.1 B   71         Israel
# 198  197.              Evan Spiegel   $11.1 B   55  United States
# 199  200.     Luis Carlos Sarmiento     $11 B   72       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment
# was posted from any YouTube Video

# %%
driver9=webdriver.Chrome('chromedriver.exe')
url9=('https://www.youtube.com/watch?v=cjjofxNQshM')
driver9.get(url9)

# %%
Comment=[]
cmt=driver9.find_elements_by_xpath("//div[@class='style-scope ytd-expander']")

for i in cmt:
    Comment.append(i.text)
    
Comment
# Out:
# ['',
#  '==================================\n00:00 - 03:47 - Raataan Lambiyan\nTanishk Bagchi, Jubin Nautiyal, Asees Kaur',
#  'Setta onn pin chyyamoo😂',
#  "Literally to lovely friends who's reading this, God bless you, and may your dreams come true, stay safe and have a wonderful day:)",
#  'Cute    song   😍😍',
#  'Very nice song',
#  'Voice of jubin out standing 😘😘',
#  'Cool melody, pure indie 😎',
#  'I love this song ❤️❤️❤️',
#  'When I listen this songs \n\nIt touches my heart and tear me u',
#  'Love this song 😘😘😘',
#  'All songs are so emotional and love this songs 😘😘',
#  'This song is beautiful',
#  'His voice is amazing... 💓',
#  'they deserved a better ending',
#  'Ek like apni maa ki lambi Umar ke dedo ❤️',
#  'Kon Kon song sunte sunte comments padhne aaye h😊😊😊like kro😄😚😚😘',
#  'Every Song is So Lovely.... I listen on Loop!! aur mood refresh ho jata hai!!\n\nSalute to our Young Captain Vikram Batra jinhone 24 ki age me Desh k liye apni jaan ki bhi parawah nahi ki....',
#  'Absolute Masterpiece',
#  'All song very very nice 😘😘😘',
#  'Beautiful music and lyrics with Punjabi touch... 💓',
#  'Eye sab song sunke muze sidnaaz ki yaad ata hain. Sana ki sid ki yaad satata hain.. miss them badly 😢',
#  "This song is very beautiful ❤️❤️ song . I love this song very much. That's is very peaceful song.",
#  'I love this song',
#  'Beautiful love songs depicting sudden unexpected  loss of Partner.',
#  'Nice song🎵',
#  'Beautiful song! Loved it',
#  'altime i tune this song...love from bangladesh',
#  'This one is one of my favorite song 😍😍😍❤❤❤😍😍😍',
#  'They are made for each other 😀😀😀',
#  'Nice song',
#  'I love this song 🧡💙♥️💚💜💙❤️💜💓♥️💙♥️💙❤️💜💚🧡',
#  'You deserved million like because this takes hours to make ....',
#  'Beautiful song 😍😍😍',
#  "Jitna suno utna Kum Lagta hai.realy it's so beautiful.full of love.😍",
#  'I love this song ❤️❤️❤️❤️❤️',
#  'Song going from one ear to other.😁🙌',
#  'Love all the songs',
#  'This song is lit 🔥',
#  'Song is shifting from one ear to another wow ❤️❤️',
#  "I just love this song..❤ I'm leaving my comment here so that whenever in a month or a year if someone liked it , I will get reminded to listen this beautiful song again",
#  'Beautiful song💗',
#  'Keep it up boddy❤️',
#  'wow this song is so amazing',
#  'ReAlly heart ❤️ toching song 👀👀👀',
#  'I can"t stop crying in 17:42- 21:59 mann bharrya 2.0😢😢',
#  'Nice song ❤️❤️',
#  'Beautiful song',
#  'All r outstanding 😫❤️❤️❤️🥺',
#  'I love this Song.... \n💞💞💞💞💞💞💞',
#  'Shershaah is the best ..❤️🇮🇳',
#  'Love it',
#  'No words for these beautiful songs just I can give is a big 💖',
#  'best music album in a while.',
#  'Raataan lambiyan song mera favourite he. Jab me ye song sunta hu to dil ko ak sukun milta he😊😀.',
#  'Beautiful Song',
#  'When I listen this song 🎵 I felt so good and really liked so much 💖',
#  'When I use headphones n close eye..my heart sing all song to my soul.. 💓🤗🥰🤗💓',
#  'Heart touching song',
#  'All the songs of Shershaah is "wow"😀❤ close your eyes, connect to earphones and listen to these marvellous songs alone is on the next level😍',
#  'Heart touching songs "',
#  'The exilent song mind free please feel the song😇',
#  'I luv all songs of this movie n i luv this movie more i cry a lots when i watch this movies its so painful but thier luv story remain alive till now in real life story i really luv their luv story my heart really hurts when i watch i cant even express my feeling in words n u respect their luv story',
#  'ye 8d song right se left jata hai fir left se right in headphones its the best 8d i have ever heared',
#  'Very like this song❤️',
#  "It's really very mesmerizing!❣️\nTry doing this with an Arijit Sir's song... The 8D effect will be of next level on his song 😌❤",
#  'The way this song edited and started that was unbelievable👍😍',
#  "The songs was like sifting form one ear to another just fabulous can't explain the feeling😌😌",
#  'Nice song',
#  'Wow what a song ❤️❤️❤️😘❤️',
#  'Wow this song 🥰',
#  'Heart touching song 🎵 ♥ 💙',
#  'I really love this song.... This song is in my heart💗💗😍😍',
#  '❤❤I love this❤❤ song❤❤',
#  'very romantic song.... lovely..',
#  'love this song',
#  'Best version of shershah songs',
#  'When i close my eyes it taken to me an another world \n\nIt was very beautiful  for me 🥰😍',
#  'I love this movie and my favourite song is JaiHind Ki Senaa ❤️❤️❤️❤️❤️!',
#  'I love 💓 this songs',
#  'loved it , very nice',
#  'Bahut hi pyare gane hai dil ko chhu jate hai ❤️❤️❤️❤️',
#  "It's a remake song❤️. However, the song looks very beautiful for new Music And Dance❤️❤️",
#  'I love this version of song can plz make it 1 hour version in 8d audio ❤️',
#  'The jobless hood endosonographically suppose because soprano typically press forenenst a heartbreaking lute. cultured, unequaled dill',
#  'Very nice song',
#  'I love this song',
#  "I am already in love with shershaah's all songs but this modification just made my whole life favourite songs possible.I can't express my feelings,now it's going to be one of my favourite YouTube channel and forever . Thanks for sending me into a peaceful world❤️✨",
#  'Heart touching song ❤️❤️',
#  'I am fell to happy ans sad 😭 but this song is heart touching 💝 and nice song love song',
#  'Amazing songs!! Amazing quality 👌👏\nI ve subscribed ur all 3 channels\nKeep going!!!💖❤',
#  'super i love this song i wish this was live',
#  'Nice song ❤💕💖',
#  'Its amazing wow🤩🤩🤩🤩🔥🔥🔥',
#  "Heart touching 🎵song's",
#  'love this',
#  'Wonder full songever',
#  'Great songs❤️❤️🙏',
#  'Lovely song ❤️❤️❤️💓💓♥️💙💙💙💙💙💙💙💙♥️♥️♥️♥️♥️💓💓💓❤️❤️💗💖💝💘🔥🔥🔥🔥🔥💞💞💞💞💞💞💞💞💞💞🖤🖤💜💙💙🤍🤎💓💖💖',
#  'Thanks for uploading 8d song ..my first song❤️',
#  'It feels like the song is running from one ear to another..😂😂😂',
#  'Bro I just feel it now. Amazing bro 👍👍🔥🔥🔥❤️❤️',
#  '5:20 heart touching part🥺🥺🧡🧡',
#  'Song is very beautiful sir Jayhind 😊',
#  'Wear the ear phone and feel the song 💖',
#  'I love this song 😘😘😘',
#  '❣️ All Time favorite song ❤️',
#  'Darshan ur voice is soulful❤️❤️\nAnd mere ek dream m se ek dream aap se milne ka h ❤️\nAll people love u❤️\nAnd ur singing is adorable 🎶🎧💜',
#  'Heart toching song.',
#  'So Nice Songs ...I love all these songs',
#  'very Priti song 😭😭🥺',
#  'My favorite  song.....God bless you beta',
#  'Just love it ❣❣🌟🌟',
#  'Nice song❤❤',
#  'op song lovely',
#  'Nice song 😍😍😍😍',
#  'THE MOST ADDICTIVE SONG I HAVE HEARD BEFORE',
#  '~Thankyou For this Music ❤️ way too SOOTHING 🌼',
#  'Nice song 👌👌☺️☺️👍👍👍',
#  'nice  💗💗',
#  "'jai hind ki sena' hasa different feel to it\n.",
#  "Beautiful song \nCan't wait to visit my love across the ocean.. pray I will one day.. listening to lovely song missing him so much.",
#  'my favourite song....i love this song.same my life story🥰🇧🇩❤️❤️😁😁this move same to same my life story!!!! so i love it',
#  'NICE SONG WITH SENSE',
#  'Superb ❤️',
#  'these songs are loveeeeeeeeeeeeeeeeeee',
#  'Nice song👌👌',
#  'The best romantic song of 2021..',
#  'Nice songs. Love this songsss💕💕💕',
#  'What a voice jubin.....\n1st one',
#  'Nice song ❤️',
#  'I love this song',
#  '😍😍Soo Lovely Songs♥️😌 Thank you for 8d 😀🤩♥️',
#  'I Love my song❤️🥰',
#  'i love this song and he is very popular song of this world',
#  'Nice song❤️😘🙏❤️',
#  'Nice song 👌👌👌',
#  'Peace full and heart tuch song',
#  'Lovely ❤👌',
#  '""I wish the person who are reading this comment may your future will be bright someday"""\'\'',
#  '""I wish the person who are reading this comment may your future will be bright someday"""\'\'',
#  'explain the feeling😌',
#  'So beautiful ❤️❤️🥰❤️',
#  'There is one girl in my class, i like her sooo much plzz pray frnds usse baat bn jaaye meri.... She is sooooo sweet........ Allah please baat chla dena, ameen..',
#  'Miss you sidnaaz ye songs sun kr tum dono ki yaad aane lgti h',
#  'Sotty khub sundor...\nAll in one,love it..',
#  'wow....mesmerizing songs.... god bless you...',
#  'Best 8D songs collection I have ever listened ❤️❤️',
#  'Delightful* keep it up...',
#  'my fevret song',
#  'Wow what a nice song I love this song really amazing',
#  'Brilliant 👌👌👌👌👌👌',
#  'Awesome songs.......    Love u 💕dear fojji',
#  'Lovely',
#  'beutiful song',
#  'Beautiful song',
#  '♥️♥️♥️♥️♥️♥️',
#  'Amazing and Lovely songs\n❤️❤️❤️',
#  'I love nepal❣️❣️❣️❣️',
#  'dang i love this\non repeat mode thanks',
#  'Hayee ye song ... ❤️💜😆😚',
#  'Love this song from Nepal🙏❤️❤️',
#  'A solute to shershaah 🎖️💂🇮🇳',
#  'AWESOME SONG',
#  'All songs are lovely',
#  'This song is very nice 😍😍😍🤩🤩🤩',
#  'Tqu for this ❤️❤️❤️❤️❤️',
#  'feel to cry when i here these songs\n😭😭😭😭😭',
#  'Dammmmnnn 🥺❤️💤\nBest 0:58 😩❤️',
#  'Love this song.',
#  'Heart touching song',
#  'So nice sound effects 😍',
#  'Can u plss upload this on spotify?',
#  'i love this song',
#  'Really remarkable',
#  'When line Ratana lambiyan comes I think about sidnaaz',
#  'Mind frash this song 😌😌😌😌',
#  'Beautiful song♥️  from Ontario Canada 🇨🇦',
#  'In earphone sound here to  there make me feel chill 😅💙',
#  'Thanks for this song',
#  'A feel the song I love it❤',
#  'Really fantastic this playlist make my travel best man',
#  'I love you song',
#  'Heart touching song...',
#  'NICE SONG I LIKE IT REAL HERO',
#  'Last song..... Heart touching 🥺',
#  'I really cried when I watched this movie 😭😭😭😭😭😭',
#  "Sing like no one is listening, love like you've never been hurt, dance like no one is watching, and live like heaven on earth.” 🌹🍃!!!\n!!!",
#  'CUTE SONG',
#  '💖💖💖❤️❤️',
#  'My fav song 😍😍😍😍😍',
#  'Extra ordinary nice song',
#  'This song is my favourite song 😍😍',
#  'But this list is too good bro.❣️❣️',
#  'Love it 🤩',
#  'This song😍😍',
#  'Mee breakup krne wala tha but just i hear shershaah song than i realize i m nothing without him 😍',
#  'I love this song ❤❤❤',
#  'Is movie k sabhi songs bahot hi acche h dil m jaise bas hi gaye h ❤️❤️❤️🥰🥰🥰',
#  'OP AUDIO QUALITY !! 🔥',
#  '3:32 best',
#  'Nice song 🥰👌',
#  'जिस भाई की आंखें मेरा कमेंट पढ़ रहे हैं उनके माता-पिता को भगवान लंबी उम्र करें और हमेशा खुश रहें 🙏😘😘😘 Subscribe',
#  'my favorite song god promise',
#  'I LIKE  THE SONG FROM MY HEART',
#  'Get well soon mom😘😘',
#  'Someone is running with speaker one ear to another 😂',
#  '"Yesteday is history"\n\n"Tomorrow is mystery"\n\n"Today is gift"\n\n"That\'s why it is called present"..❤🤩👍',
#  'Awesome... Im use headphone... N missed my ex.... Now m a mother of a son',
#  'Very nice song very nice',
#  'I love song',
#  '❤',
#  "best song i love dis song so much '''",
#  'I love you song 💞💞💕💕💕',
#  'Heart touching songs',
#  '😍',
#  'THIS SONG OUTSTANDING',
#  'I love songs❣️❣️❣️❣️❣️❣️',
#  'Very nice song🔥🔥🔥🔥🔥🔥',
#  'Hey listener, Believe me this jukebox is enough to play a whole wedding ceremony.❤️',
#  'nice song༺☆☆༻',
#  'i love it',
#  'so lovely song . I feel so better ☺️🤱',
#  'Fev Song😍😘💞🎶🎧🎵',
#  'Wow! awsome song.',
#  'Nice song ⚔️♥️🇮🇪',
#  'I will listen every day because this is one of my favorite song',
#  '🤘🤘',
#  'Love you bro ❤',
#  'Wahh❤',
#  '❤❤❤❤❤❤❤❤❤❤',
#  'Meri maa hospital me admit hai 😭\nPlease pray for my mom 🙏',
#  'I really appreciate 🙏dimple ji. She is great 👍.',
#  'Amazing',
#  'I really love❤❤ this song🎵🎵',
#  'Veri nice song 😍😍😍👌👌👌👌✌✌✌💕💕💕💕💕❤❤❤❤❤❤💖💖💖',
#  'After student of the year shershah is my favorite movie  of Sidharth Malhotra',
#  'Mind blowing💝',
#  'The detailed holiday thoracically surround because editorial ethnically saw opposite a messy brochure. serious, arrogant lift',
#  'Wow what  a gd mashup of song.',
#  '♥️♥️♥️♥️♥️♥️♥️ Be happy song',
#  '😍',
#  'Mind blowing song',
#  'now i can take a nap thank you',
#  'After hearing this , my ear be like , Idhar chala Mai udhar chala , Ja ne Mai pisal Gaya 😂😂😂',
#  'I have lost my husband this April  but whenever I listen this song I feel like he is around me',
#  'Osm song❤️💐',
#  '😭😭😭 this song touch my heart 💟💟💟💟',
#  'I love this all songs love this movie',
#  'best 8D songs yar',
#  'wow Amazing',
#  'Listening at exam preparation time.  helpful',
#  'Jubin Nautiyal always legend',
#  'Very nice',
#  "i still have not watched this movie due to sidharth's acting",
#  'Nice❤❤',
#  'No word guys☺😊☺😊',
#  'Beautiful song',
#  'Wow feeling better specially ranjha song',
#  'আমার প্রিয় নায়ক সিদ্ধার্থ',
#  'Nice I can feel it 👍',
#  'So beautiful song and I love song 💘💘💘💘',
#  'Best album after Kabir Singh.',
#  '⚡I really love it when the notification show up someone liked your comment and you have a new subscriber🥺🤧',
#  'I love first and second song 🥰🥰🥰🥰🥰😍😍😍😍🥰🥰🥰🥰😘😘😘',
#  'Your song 1.25x speed is very nice osm song',
#  'Khya song hey  my favorite song ever',
#  'We need such movies......one more this time.....on "Arun Khetrapal"',
#  '❤❤❤❤❤❤❤❤❤❤',
#  '😍😍',
#  'All songs are very beautiful & siddhart malhotra is very nice role in this movie 😘😘',
#  'Mera ❤ muskuraate hue\n ro padaa 😭\nAsa bhi kya paana tha ❤ ko \njiske liye maine khud ko ',
#  'Shershaah is not a movie its an emotion.',
#  'Op song bro/sis',
#  'গানটা শুনলে মনে হয় জীবনটা অনেক সুন্দর 🖤🥀',
#  'My fav movie and all songs are also fav I am just satisfied to all things when i listen these songs and those lines of ranjha ve mera dola ni aaya bs kya btau',
#  'Nice song ❤️😘❤️😘❤️.',
#  'I love this song 🎵😊',
#  'bohat sundar song 🥰🥰🥰🥰\nAcca laga 🥰🥰🥰 thanks bro 🥰🥰🥰 dubara ascha song dekhna chahatu \nঅসাধারণ লাগলো গান টা ধন্যবাদ ভাই এইরকম গান আরও দিবেন আশা করি 🥰🥰🥰',
#  'How  can i  say  in this movie \ni  am already see in this movie awesome \n\nloveded',
#  'nice song',
#  'nice song',
#  "Heart❤toching😢song really I'm big fan to vikram batra sir🙏I'm salute you sir👏",
#  'achha bajae ho :)',
#  'Nice 😍',
#  'So cute song',
#  'supop.....songs..',
#  'Very very good and beautiful .I love this song.',
#  'Nice song bro 🥰',
#  'Meri maa hospital me admit hai 😭\n\nPlease pray for my mom 🙏',
#  'Yo.. bro 🤘🖤🖤🖤',
#  'My favourite movie shershah yeh Dil maange more we are proud captain Vikram bhatra he was real hero our country',
#  'Mast song ever',
#  'Your are saying right just close eyes my mind get relax because what you are saying for others i like this type of peoples😘😘😊😊',
#  'Tum agr manaoge to Maan jaunga...kbhi tumhe yaad meri aaye..palko ko apne Utha lena.....love u...sona',
#  'magic ...!',
#  'I have a orginal earphone of jbl ❤ really i feel this is usefull😅😊',
#  'I love this song',
#  'Why people appreciating the video uploader instead of appreciating singers 😏😞',
#  "8D is not only panning the music from left to right. I heard these songs on earphones (Master & Dynamic MW07 PLUS), headphones (Bose QuietComfort 35 II) and it doesn't differ in anyway. Please do not fool people by stating 8D and all. It should say panning of music from left to right.",
#  '✨✨🥀',
#  'These songs are ❤......(😜no words) ....... A love story....jo sabko sunai jayegi har baar.....💕😍',
#  'My headphones be like : kaha chaliye kaha  chaliye😂🤣',
#  '❤❤',
#  '😭😭😭😭💟💟',
#  'Osm🤩 Heart touching song 💓💓',
#  'Nice song 😇',
#  'Dekh bhai thoda expectation bdh gya h. Keep Doing this. Songs are awesome, n that too in one go❤',
#  'Nice song 😍😍😍😘',
#  'I 💕💕💕💞💞 love songs',
#  'Nice👏👍',
#  '😍😍😍WOW',
#  '3M views amazing broh keep going 👌👌👌',
#  'शानदार भाई 🥇🏅🙏🏻',
#  'Ooh my good so good song I loving like this song ☺️☺️☺️☺️☺️☺️☺️☺️😊',
#  'Plz Jass manak songs ❤️',
#  'Mast 8D yaar, laga jaise speaker pe play ho raha hai, but actual me sirf mujhe suniye de raha tha!',
#  'I love this song',
#  'Kitne javan humare liye shaheed hue jai hind jai bharat 🇮🇳🇮🇳',
#  'Niceeeee ❤',
#  'Best song',
#  'What a song',
#  'exllent song',
#  'Nice dude ❤️',
#  'omg ....❤️❤️❤️❤️❤️🥰🥰🥰🥰🥰🥰🥰🥰🥰😘😘😘🤗🥺',
#  'Nice song',
#  'I love song Ranjha',
#  'Whenever I listen Ranjha & Mann Bharryaa 2.0 ,It remembers me of Siddharth 😭😭😭😭😭😭😭😭😭 What about shehnaz 😭😭😭😭😭',
#  'Wow!!!!!!!!!!!! \nSong is so cute, good',
#  'wow thks for this actualy i was waiting for it',
#  '#8D hai toh mood sahi hai 💯.',
#  'Woo I love thes song',
#  'Nice editing ❤️',
#  'Bht achi edit hai hai audio ki ek no.  Keep it up',
#  'My life love you kalu',
#  '💙💙💙💛💛💛❤❤❤',
#  'how can someone dislike this vid',
#  'Sheesha move all song like mind and hard touched my life 😌❤❤🔥🔥😇',
#  'My heart',
#  '❤️❤️',
#  'Wow 🥰',
#  'nice song',
#  'Wow',
#  'nice song',
#  'nice song',
#  'Ilove song',
#  'My hart song',
#  'Nice song 👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍 of 👍',
#  'इतना नशा शराब मे नहीं है जितना इस गाने मे नहीं है। सुबह से शाम हो गया पर मन ही नहीं भर् रहा है। सुने जा रहा हूँ',
#  'so sweet song',
#  'Lovely',
#  '🤩💝💞💖',
#  'Such A Lovely Song....I love the all song',
#  '💗💗💗💗💗💗💗',
#  'I Love all song',
#  '♥️🇮🇳',
#  'All best song of in happy',
#  'Favorite ❣️',
#  '❤❤',
#  '❤️❤️❤️❤️',
#  'All songs very nice',
#  'My fv song love you song ,💞💕💕💞💞💕💕💞💕💞💞',
#  'So Beautiful 😍😍',
#  'it is the most beautiful and rare diamond in the world',
#  'Awesome 👍',
#  'good song',
#  'Palak muchhal voice😍😍😍🥰🥰😘😘😌😌',
#  '❤️❤️❤️❤️💜💜',
#  'Nise song 😭😭😭',
#  'Bahut shaandaar voice h jubin nautiyal',
#  'Nice',
#  'My fav song',
#  'Bhai songs ko description mein credit kaise dete hain? 😍❤',
#  '❤️❤️',
#  'The last song 😭',
#  'i love this movie💖 \nBharat mata ki \nJay',
#  '👌😍',
#  'Very nice song',
#  'Love 💞 you',
#  "Nice song's",
#  'Very very good song',
#  '😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍',
#  'Butefull song 💗💘🌸🥰😃',
#  'Nice 🎧🎶🎶🎶',
#  'Very very good song',
#  'when I first heard these 8d songs,\nME:- what happen to my headphones?',
#  'Awesome',
#  "It's great 👍song.",
#  'Lovely',
#  'Superb',
#  'If Mann Bharrya Song didnt give you goosebumps then guys you need to see the doctor .. Love this channel and subscribe too.. :)',
#  'Mast song 🎵♥❤💕👌😍🎵♥❤💕',
#  'Excellent.',
#  'which software u use for 8d music',
#  'Raataan ❤️❤️❤️,💙💚💛🧡💖',
#  'WOW very nice song',
#  'Nice song',
#  'Favorite song ❤️❤️',
#  'My love song',
#  'Very very nice song \nVery super 🎵🎶😍😍',
#  'Nice song',
#  'Nice song',
#  'I love this song 💕💕👌👌👌❤️❤️❤️❤️❤️',
#  '🥰😍❤️ Naic song',
#  'Love you song my favourite 👌',
#  'Best song',
#  'mast song gjb hai yrrr is song se pahle sabke favrouite ajeeb ajeeb the......',
#  'Beautiful so ng sir',
#  'Headphone 🎧 back to back right left I love it love uhh bhai ❤️😘',
#  'Fav 1❤️',
#  'Iloveyou, song 👌👌👌👌♥️♥️♥️♥️♥️',
#  'Experience it best with headphones',
#  'I love this song 😍😍🥰😍',
#  'nice song sir ji',
#  'Fantastic awesome 👍👍',
#  'Nice song sir',
#  'Dil Chu liya,🥰🥰🥰🥰',
#  'Nice',
#  '😍😍😍🥰🥰🥰😻😻😻',
#  'Buetyfull song',
#  'Nise.song.....😘😘😘😘😘❤️❤️❤️',
#  'I love at song',
#  'I love  this  song 🥰🥰🥰🥰🥰🥰',
#  'Nice song😘😘❤❤😍😍🤩🤩',
#  'Mojja song🌟🌟',
#  'very nice song',
#  'Very nice❣️💞',
#  'I love Shershah movie songs. All songs are heart touching and nice 👌 💓 ❤',
#  'WOW,😍😍💋💋😘👍🥰🥰',
#  'Super romantic song',
#  'My best song',
#  '😍😍❤️',
#  'Vary nice film of our Indian Army Kargil war Hero life True Story of their Love life and Sacrifice towards of my country. Salute Param Vir Chakra Cap. Vikram Batra. Jai Hind Jai Jawan.🇮🇳🇮🇳🇮🇳',
#  'Dil Ko chuuu gyaaaa yar',
#  'Nice song',
#  'Nice song',
#  'Nice song',
#  "When I closed my eyes and when I was hearing that and then when I opened my eyes I was soooooo relax and I feel so gud that I can't express",
#  'dedicate to my darling...🤣🤣🤣🤣🤣🤣',
#  'Kis idiot ne issko dislike kia🤭🤭🤭',
#  'Naic song 👍👍👍👍👍👍👍👍👍👍',
#  'nice song i love song',
#  '🙏🏼🙏🏼🙏🏼🙏🏼',
#  'I miss you  Captn Vikrm Bttra sir...🙏🙏😭😭😪😪⚔️⚔️⚔️⚔️⚔️⚔️⚔️🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳❤❤❤❤💪💪💪💪💪..jai Hind sir...',
#  'Ranjha and raatan lambiya play in reapat mood',
#  'Music 😍😍',
#  'Nice song❤️❤️❤️❤️❤️',
#  '1and 2 most favourite one songs of min',
#  'Nice bro👌😍',
#  'Song 😇😇😇❤❤',
#  'This remix song very nice',
#  '👌👌👌👌👌❤️👌👌👌👌👌',
#  'Mast ha bahi 👍❤️👍👍',
#  '😘😘',
#  '😊😊💝 love songs 😘',
#  'Wow nice song',
#  "I only click this vedeo because I have to test my mom's new Blootooth earphones 🤣🤣🤣🤣😎😎😎😎",
#  'lovely song 💘💘💘',
#  'sir please do same with dil ko karar aaya of neha kakkar 😍😘😘❤❤❤',
#  'ranjha is my favowrite song',
#  'A song jitna suno utna kaam hi lgta hai',
#  'Jaan nikal leta hai ye gaana I feel nothing',
#  'Mind blowing 👌',
#  'Very good song',
#  'Only switch Audio template left and right \nIt’s not Extraordinary eating 😂😂🤣',
#  '❤❤❤❤❤❤❤❤',
#  '💖💖💖💖',
#  '😇😇😇❤️❤️❤️💖💖',
#  'Nice song',
#  'Very nice songs',
#  'Very nice songs',
#  '❤️',
#  'Wow Jubin Nautiyal ji Dil Khush Ho gaya after listening this song. Ke raate lamaya lambaya re. After Marjawa, after Kabir Singh Sher Shah.',
#  'Bhut hard song hai bhai ☺️☺️ maazza aa gya',
#  'The Shershaah is real hero',
#  '🥰',
#  'Shershaah movie all song very very good i love this ❤👌👌👌👌👌👌👌👌 M👈',
#  'Heart touching songs 😇❤️❤️',
#  '❤️♨️',
#  '❤️',
#  'What a Song\nPlz Rataan lambiyaa 2 bhi hona chayeee jus trha Filhall 2 ayaaa plz',
#  '❤️❤️',
#  'My favourite song ❣️',
#  'nice song',
#  'Nice song 🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰',
#  'Jobin national  you are great',
#  '❤️',
#  'I love it',
#  'Love 😍😍😍😍😘😘😘😘😘',
#  '😌😌😌',
#  'Nice song👍️👍️👍️👍️',
#  'I love this song',
#  'Heart touching',
#  '❤️',
#  '💞💞💞',
#  'Osm 👍',
#  'Very nice song#🎶🎤',
#  'I love  the way of kaira portrays dimple cheema ji this create a lots of  respect among us for dimple ji',
#  'Very nice song#🎶🎤',
#  'I like it',
#  'Nice 👍☺️',
#  'Nice song',
#  'Heart touching song ❤️😌 just feel it 😌',
#  'My Work out time was great ❤ kaha kaise time chala gya kch pata nahi chala 🍃❤✨',
#  '💖💖💖💖',
#  'I❤️ u this is song',
#  'Hear in your earphones its amazing',
#  '😍😍',
#  'Awesome men outfit get up sense',
#  'Such nice',
#  '❤🌹💐🤲',
#  '❤️❤️❤️',
#  'Now I knew that my headphones are working properly.',
#  'Soon this song cross 10 million on this channle 😀',
#  'Creator is awesome',
#  'I love this song',
#  'nice song',
#  'Ye sab gana ko roj din mai 5 ya 6 baar sunti hu or aapne aasan kar diya dundhna nhi pdega thank you🌹',
#  'I love this  movie  and  song',
#  '😍😍😍😍😍',
#  'Bhai ye song Dil ko chuh diya 🥀🥰',
#  '❤️❤️❤️❤️',
#  'Nice Songs..😘😘😘',
#  'Palak muchal😍',
#  'Very nice 👍👏😊',
#  'Iove you song😘😘😘😘',
#  'Bro no words to say😭😭😍😍😍🥳🥳',
#  "It's very beautiful song ❣️",
#  '❤️❤️❤️❤️',
#  'aisa lag raha hai ki baju mei gana chal raha hai awesomee😅',
#  '👌👌🥺',
#  'Use headphone close your eye and also move your head to and pro.।।।। And also sing as well.।।।।।।।',
#  'Song is lovely',
#  '👌👌👌',
#  'AII song very very nice',
#  'Nice',
#  'Nice song',
#  '😍',
#  'Nice',
#  'Nice',
#  'Wow that is so sweet song',
#  'Shershaah album',
#  'jubin voice😘😘😘  sid looking damn😍😍 cute',
#  '8D SONGS OP AND NICE BRO',
#  'This songs is very nice',
#  'Raatan lambiyan😍\nRaanjha 😭😭😭',
#  'Wow nice song',
#  'Maan bharryaa song is my favt ❤❤ kash aisa ho sakta rab de pyer baijani teri jaga ve jani mout mainu laijani 💔💔 my favt lines',
#  'Very nice 👍👍👍👍👍🥰',
#  'I am impresse 😍😘😘',
#  '😍😍😍😍😍🤩🤩💖❤❤❤❤❤',
#  'ಆಕಾಶದಲ್ಲಿ ಹಾರಾಡುವ ಪಾರಿವಾಳ \u200cಹಾಗೆ ಇಧೆ',
#  'I love my India',
#  '✨🤦🥀',
#  'Bro maja aa gaya❤️❤️',
#  'My favorite one is ranjha',
#  '❤️❤️❤️❤️❤️',
#  "Really I'm telling true to everyone that this song is heart touching 💓and my favourite song 💕💕😊 so one like from me for this song👍who is gentleman 😍 present here 😁 from now 07:29 6th sep 2021 😊",
#  'Shaadi Mein Zaroor Aana \nit is most love',
#  '👍👍',
#  'Jhakkkas ✨🔥💫',
#  'aap ka ye wala collection bahut mast hai thanks',
#  'Heart touching song 😍',
#  'Mast bro',
#  'My song "Tikli " Regional language of jharkhand',
#  'Superrrr',
#  '😄😄😊',
#  '💕👌👏',
#  '😍😍😍😍🎂🎂😘',
#  'Nice 8d songs',
#  'Mast song',
#  'Nice song ❤️☺️',
#  'Es song me to piche se esa lg rha h. Jesi ki avaj idhar chli. Udhar chli',
#  'Very beautiful song very beautiful song please apna number de dijiye please please aap Acche song Aap Jo sath mein song aap aapane aur aapki didi Ne wale very nice thank you',
#  'Meri mummy ko corona ho gya hai please pray for them to get well soon 🙏',
#  '😘😘',
#  '👍👍👍👍Hii❤❤🥰🥰',
#  'I love Indian army',
#  '👌',
#  '👌',
#  'Yes 🥰',
#  '👌👌👌👌',
#  'its really heart touching song',
#  'I love you song',
#  'Wow 👌👌👌👌👌',
#  'Song son ke ❤️❤️😓kuch kuch huta hai😭',
#  '👌👌✌️',
#  'nyc song \n\n\nlove this song',
#  'Anyone else like this song better than Hello ?',
#  'Awesome song I love दिस song',
#  '👌👌👌👌👌👌👌',
#  'Nice',
#  'Just love this song👍❤❤❤',
#  'Nice',
#  'Mast',
#  'Nice',
#  'Super',
#  "After sid death i m just crying 😭😭😭😭😭 i can't believe",
#  'I like it',
#  'I am here for mann bharya',
#  'Veri nice 👍',
#  '𝓞𝓹 𝓿𝓲𝓭𝓮𝓸 𝓸𝓯😭😭😭😭😭😭😭',
#  '😍😍😍😍',
#  'nise song',
#  'My favourite song raataan lambiyaan',
#  'Love liye snd',
#  'Nice bro',
#  'Fabulous 🔥',
#  'Superb  song hartouching😘😘',
#  'Sir big Fan sir\nSir big Fan sir\nSir big Fan sir',
#  'OP SONG',
#  'I love this song all song jitni baar bhi suno mn krta h ki bs ek baar or 🤟🤟🤟🤟',
#  'Best nothing to say more keep it up 👍💓🥰🥰💖💯',
#  '♥️',
#  'thank u sir for making ths video',
#  'This video has to come in trending.',
#  'Just feel....',
#  'Amazing 👌',
#  'Teri meri galaa ho gayi mashhoor ❤️❤️❤️',
#  'Nice',
#  'I am listing this song and i an do emotinao',
#  'Nice movie song All 🤘🏻🤘🏻']

# %%
len(Comment)
# Out:
# 622

# %%
Time=[]
time=driver9.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")

for i in time:
    Time.append(i.text)
    
Time
# Out:
# ['5 days ago',
#  '1 day ago',
#  '1 week ago',
#  '2 weeks ago',
#  '6 days ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '3 days ago',
#  '1 week ago (edited)',
#  '1 week ago (edited)',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '6 days ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 days ago',
#  '6 days ago',
#  '1 week ago',
#  '1 week ago',
#  '5 days ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '5 days ago',
#  '1 week ago',
#  '1 day ago (edited)',
#  '5 days ago',
#  '2 weeks ago',
#  '5 days ago',
#  '3 days ago',
#  '2 weeks ago',
#  '4 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '6 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '3 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 day ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 day ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 days ago',
#  '2 weeks ago',
#  '5 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '4 days ago (edited)',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '5 days ago',
#  '2 weeks ago',
#  '3 days ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 days ago',
#  '1 week ago',
#  '2 weeks ago (edited)',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 days ago',
#  '4 days ago',
#  '6 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago (edited)',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '4 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago (edited)',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago (edited)',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '4 days ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago (edited)',
#  '6 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '6 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '23 hours ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 day ago',
#  '7 hours ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '6 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago (edited)',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '6 days ago',
#  '2 weeks ago',
#  '6 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 day ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '18 hours ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '6 days ago',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '22 hours ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '4 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '5 days ago',
#  '1 day ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '6 days ago',
#  '1 week ago',
#  '6 days ago',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '5 days ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '3 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '6 days ago',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '6 days ago',
#  '2 weeks ago',
#  '3 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 day ago',
#  '1 week ago',
#  '4 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '5 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '5 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '3 days ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 day ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '1 week ago',
#  '4 days ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 week ago',
#  '2 weeks ago (edited)',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '3 days ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago',
#  '1 week ago',
#  '2 weeks ago',
#  '2 weeks ago']

# %%
Comment_Upvote=[]
cu=driver9.find_elements_by_id("vote-count-middle")

for i in cu:
    Comment_Upvote.append(i.text)
    
Comment_Upvote
# Out:
# ['32',
#  '8',
#  '12',
#  '24',
#  '9',
#  '5',
#  '7',
#  '8',
#  '8',
#  '6',
#  '21',
#  '8',
#  '19',
#  '178',
#  '19',
#  '21',
#  '3',
#  '11',
#  '12',
#  '10',
#  '3',
#  '3',
#  '12',
#  '30',
#  '2',
#  '5',
#  '2',
#  '4',
#  '11',
#  '7',
#  '3',
#  '2',
#  '2',
#  '1',
#  '2',
#  '3',
#  '2',
#  '10',
#  '57',
#  '13',
#  '3',
#  '2',
#  '2',
#  '1',
#  '4',
#  '24',
#  '2',
#  '',
#  '1',
#  '3',
#  '11',
#  '6',
#  '2',
#  '2',
#  '14',
#  '10',
#  '2',
#  '40',
#  '1',
#  '1',
#  '46',
#  '1',
#  '1',
#  '12',
#  '4',
#  '34',
#  '14',
#  '1',
#  '1',
#  '2',
#  '12',
#  '17',
#  '1',
#  '1',
#  '1',
#  '39',
#  '1',
#  '2',
#  '2',
#  '1',
#  '10',
#  '5',
#  '2',
#  '2',
#  '1',
#  '27',
#  '5',
#  '1',
#  '12',
#  '1',
#  '10',
#  '2',
#  '1',
#  '1',
#  '2',
#  '19',
#  '1',
#  '1',
#  '1',
#  '1',
#  '11',
#  '1',
#  '2',
#  '1',
#  '3',
#  '6',
#  '2',
#  '1',
#  '2',
#  '1',
#  '9',
#  '1',
#  '2',
#  '1',
#  '5',
#  '11',
#  '2',
#  '2',
#  '1',
#  '10',
#  '19',
#  '1',
#  '1',
#  '1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '',
#  '3',
#  '2',
#  '2',
#  '1',
#  '2',
#  '6',
#  '1',
#  '1',
#  '1',
#  '2',
#  '5',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '2',
#  '1',
#  '',
#  '19',
#  '2',
#  '2',
#  '1',
#  '2',
#  '7',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '',
#  '1',
#  '1',
#  '1',
#  '17',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '',
#  '2',
#  '1',
#  '1',
#  '16',
#  '1',
#  '1',
#  '1',
#  '1',
#  '19',
#  '1',
#  '1',
#  '1',
#  '1',
#  '4',
#  '2',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '',
#  '1',
#  '',
#  '18',
#  '1',
#  '2',
#  '1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '23',
#  '2',
#  '1',
#  '1',
#  '13',
#  '3',
#  '2',
#  '2',
#  '1',
#  '2',
#  '8',
#  '',
#  '2',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '2',
#  '1',
#  '20',
#  '1',
#  '2',
#  '2',
#  '1',
#  '25',
#  '1',
#  '1',
#  '1',
#  '1',
#  '6',
#  '2',
#  '1',
#  '',
#  '2',
#  '6',
#  '1',
#  '1',
#  '1',
#  '1',
#  '11',
#  '1',
#  '',
#  '2',
#  '1',
#  '4',
#  '1',
#  '1',
#  '1',
#  '1',
#  '6',
#  '2',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '2',
#  '2',
#  '1',
#  '7',
#  '2',
#  '2',
#  '1',
#  '1',
#  '10',
#  '2',
#  '1',
#  '1',
#  '1',
#  '12',
#  '1',
#  '2',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '2',
#  '',
#  '5',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '',
#  '1',
#  '1',
#  '23',
#  '1',
#  '1',
#  '1',
#  '1',
#  '76',
#  '',
#  '1',
#  '',
#  '1',
#  '3',
#  '2',
#  '2',
#  '1',
#  '2',
#  '3',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '38',
#  '1',
#  '1',
#  '1',
#  '1',
#  '12',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '1',
#  '2',
#  '1',
#  '5',
#  '2',
#  '1',
#  '1',
#  '1',
#  '5',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '12',
#  '1',
#  '1',
#  '1',
#  '1',
#  '15',
#  '1',
#  '2',
#  '1',
#  '1',
#  '9',
#  '1',
#  '1',
#  '1',
#  '1',
#  '9',
#  '2',
#  '1',
#  '1',
#  '1',
#  '18',
#  '1',
#  '1',
#  '1',
#  '1',
#  '6',
#  '1',
#  '1',
#  '',
#  '1',
#  '8',
#  '1',
#  '',
#  '1',
#  '1',
#  '32',
#  '',
#  '1',
#  '1',
#  '1',
#  '12',
#  '2',
#  '1',
#  '1',
#  '1',
#  '8',
#  '1',
#  '1',
#  '1',
#  '1',
#  '11',
#  '1',
#  '2',
#  '1',
#  '1',
#  '3',
#  '',
#  '1',
#  '1',
#  '2',
#  '8',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '2',
#  '',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '18',
#  '1',
#  '1',
#  '1',
#  '1',
#  '30',
#  '1',
#  '1',
#  '1',
#  '1',
#  '10',
#  '1',
#  '',
#  '2',
#  '1',
#  '7',
#  '2',
#  '1',
#  '1',
#  '1',
#  '6',
#  '',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '13',
#  '1',
#  '1',
#  '1',
#  '1',
#  '9',
#  '1',
#  '1',
#  '1',
#  '',
#  '8',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '2',
#  '5',
#  '1',
#  '1',
#  '2',
#  '',
#  '10',
#  '1',
#  '1',
#  '1',
#  '1',
#  '13',
#  '1',
#  '1',
#  '1',
#  '2',
#  '11',
#  '1',
#  '1',
#  '1',
#  '2',
#  '6',
#  '1',
#  '2',
#  '1',
#  '',
#  '3',
#  '1',
#  '1',
#  '2',
#  '1',
#  '4',
#  '1',
#  '1',
#  '1',
#  '1',
#  '30',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '1',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '2',
#  '1',
#  '6',
#  '2',
#  '1',
#  '1',
#  '1',
#  '6',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '2',
#  '',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '4',
#  '1',
#  '',
#  '2',
#  '',
#  '7',
#  '1',
#  '1',
#  '2',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '6',
#  '',
#  '2',
#  '1',
#  '1',
#  '5',
#  '2',
#  '1',
#  '1',
#  '2',
#  '7',
#  '2',
#  '1',
#  '1',
#  '1',
#  '11',
#  '1',
#  '',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '1',
#  '1']

# %%
len(Comment),len(Time),len(Comment_Upvote)
# Out:
# (622, 620, 620)

# %%
df9=pd.DataFrame()

df9['Comments']=Comment[2:]
df9['Upvote']=Comment_Upvote
df9['Posted Time']=Time

df9
# Out:
#                                               Comments Upvote  Posted Time
# 0                              Setta onn pin chyyamoo😂     32   5 days ago
# 1    Literally to lovely friends who's reading this...      8    1 day ago
# 2                                    Cute    song   😍😍     12   1 week ago
# 3                                       Very nice song     24  2 weeks ago
# 4                       Voice of jubin out standing 😘😘      9   6 days ago
# ..                                                 ...    ...          ...
# 615                                          Amazing 👌      4  2 weeks ago
# 616            Teri meri galaa ho gayi mashhoor ❤️❤️❤️      1  2 weeks ago
# 617                                               Nice      1   1 week ago
# 618        I am listing this song and i an do emotinao      1  2 weeks ago
# 619                           Nice movie song All 🤘🏻🤘🏻      1  2 weeks ago
#
# [620 rows x 3 columns]

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from
# https://www.hostelworld.com/ in “London” location. You have to scrape hostel name,
# distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms
# from price, facilities and property description

# %%
driver10=webdriver.Chrome('chromedriver.exe')
url10='https://www.hostelworld.com/'
driver10.get(url10)

# %%
tag=driver10.find_element_by_xpath("//input[@class='search-input']")
tag.send_keys('London')

# %%
btn=driver10.find_element_by_xpath("//div[@class='search-button']/button")
btn.click()

# %%
import time

# %%
Name=[]
for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    name=driver10.find_elements_by_xpath("//h2[@class='title title-6']")
    for j in name:
        Name.append(j.text)
    
len(Name)
# Out:
# 85

# %%
Distance=[]
for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    dis=driver10.find_elements_by_xpath("//a[@class='show-on-map']")
    for j in dis:
        Distance.append(j.text)
Distance
print(len(Distance))
# Out:
# 85

# %%
Rating=[]
for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    rating=driver10.find_elements_by_xpath("//div[@class='rating rating-summary-container big']")
    for j in rating:
        try:
            Rating.append(j.text.split('\n'))
        except:
            Rating.append("-")
len(Rating)
# Out:
# 85

# %%
Review=[]
for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    re=driver10.find_elements_by_xpath("//div[@class='keyword']//span[1]")
    for i in re:
            Review.append(i.text)
len(Review)
# Out:
# 88

# %%
R1=Review[:85]
len(R1)
# Out:
# 85

# %%
Total_Review=[]

for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    tr=driver10.find_elements_by_xpath("//div[@class='reviews']")
    for j in tr:
        try:
            Total_Review.append(j.text)
        except:
            Total_Review.append("-")
            
len(Total_Review)
# Out:
# 85

# %%
Price=[]

for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    pr=driver10.find_elements_by_xpath("//div[@class='price-col']")
    for j in pr:
            try:
                Price.append(j.text.replace('From\n',' '))
            except:
                Price.append('-')
                
len(Price)
# Out:
# 170

# %%
P=Price[::2]
D=Price[1::2]

# %%
Url10=[]

for i in range(1,4):
    pg='https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-09-26&to=2021-09-28&guests=2&page='+str(i)
    driver10.get(pg)
    time.sleep(10)
    url=driver10.find_elements_by_xpath("//h2[@class='title title-6']/a[1]")
    for j in url:
        try:
            Url10.append(j.get_attribute('href'))
        except:
            Url10.append("-")
len(Url10)
# Out:
# 85

# %%
Property=[]
for i in Url10:
    driver10.get(i)
    time.sleep(3)
    pd=driver10.find_element_by_xpath("//div[@class='collapsible']/div[2]")
    try:
        Property.append(pd.text)
    except:
        Property.append("-")

# %%
len(Property)
# Out:
# 85

# %%
import pandas as pd

# %%
df10=pd.DataFrame()

df10['Hostel Name']=Name
df10['Distance From City Center']=Distance
df10['Rating']=([item[0] for item in Rating])
df10['Review']=R1
df10['Total Review']=Total_Review
df10['Privat Price']=P
df10['Drom Price']=D
df10['Property Discription & Facility']=Property

df10
# Out:
#                              Hostel Name  \
# 0                 London Waterloo Hostel
# 1   St Christopher's Inn - London Bridge
# 2               Barmy Badger Backpackers
# 3        Wombat's The City Hostel London
# 4                Prime Backpackers Angel
# ..                                   ...
# 80                             The Dover
# 81                      23 Matheson Road
# 82                      Park Hotel Essex
# 83                       Cranbrook Hotel
# 84                            St. Athans
#
#                             Distance From City Center     Rating     Review  \
# 0         Hostel - 0.7km from city centre Show on Map        7.2   Fabulous
# 1         Hostel - 1.8km from city centre Show on Map        7.0     Superb
# 2         Hostel - 5.5km from city centre Show on Map        9.7   Fabulous
# 3         Hostel - 3.6km from city centre Show on Map        8.8     Superb
# 4         Hostel - 3.6km from city centre Show on Map         10   Fabulous
# ..                                                ...        ...        ...
# 80         Hotel - 1.9km from city centre Show on Map  No Rating  Very Good
# 81  Bed and Breakfast - 6.2km from city centre Sho...        6.9  Very Good
# 82        Hotel - 24.1km from city centre Show on Map  No Rating     Superb
# 83        Hotel - 14.8km from city centre Show on Map  No Rating  No Rating
# 84  Bed and Breakfast - 2.9km from city centre Sho...        7.6     Rating
#
#           Total Review       Privat Price          Drom Price  \
# 0    101 Total Reviews   Privates  Rs5368       Dorms  Rs1456
# 1    190 Total Reviews   Privates  Rs4145       Dorms  Rs1254
# 2   1763 Total Reviews   Privates  Rs6268       Dorms  Rs2123
# 3    394 Total Reviews   Privates  Rs8427       Dorms  Rs1781
# 4     41 Total Reviews   Privates  Rs8786       Dorms  Rs2392
# ..                 ...                ...                 ...
# 80     2 Total Reviews  Privates  Rs12212  No Dorms Available
# 81     2 Total Reviews  Privates  Rs13587  No Dorms Available
# 82     6 Total Reviews   Privates  Rs4701  No Dorms Available
# 83   108 Total Reviews   Privates  Rs4549  No Dorms Available
# 84    58 Total Reviews   Privates  Rs6470  No Dorms Available
#
#                       Property Discription & Facility
# 0   Food & culture lovers, assemble!\nThe Rose & C...
# 1   At the The Finnish Church in London, we offer ...
# 2   Saint James Backpackers, set in a classic Vict...
# 3   The Green Man Bestplace Inn is next door to Ed...
# 4   Mornington Camden Hostel is a high class spaci...
# ..                                                ...
# 80  With friendly staff, excellent service and an ...
# 81  This pretty Victorian town house on a quiet st...
# 82  This Hotel is the right choice for visitors wh...
# 83  We are located about twenty minutes by tube fr...
# 84  The St Athans Hotel is a proudly simple, famil...
#
# [85 rows x 8 columns]
